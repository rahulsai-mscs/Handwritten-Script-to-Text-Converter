# %%
# %run main.py
# Out:
# ArgumentParser(prog='main.py', usage=None, description=None, formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)
# Validation character error rate of saved model: 8.654728%
# Python: 3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:47:18) [MSC v.1916 64 bit (AMD64)]
# Tensorflow: 2.13.0
# Init with stored values from ../model/snapshot-24
#
#
# The Handwritten Script in the Image Recognized Without the Spelling Correction is:  or work on like leve
#
# The Recognized Handwritten script after the Correction is:  or work on like live

# %%
# %run upload.py
# %tb
# Out:
#  * Serving Flask app 'upload'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5050
#  * Running on http://192.168.0.191:5050
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Feb/2024 12:58:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2024 12:58:07] "GET /static/css/jumbotron.css HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2024 12:58:07] "GET /static/css/bootstrap.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2024 12:58:07] "GET /static/img/Brand_Final.png HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2024 12:58:07] "GET /static/js/bootstrap.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2024 12:58:07] "GET /static/js/jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2024 12:58:07] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Feb/2024 12:58:11] "GET /upload_page HTTP/1.1" 200 -
# ...

# %%
# !pip install autocorrect
